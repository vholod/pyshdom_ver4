# %% [markdown]
# ## Make Mie Tables
#
# This is a short tutorial on generating Mie properties for monodisperse sizes using pyshdom.

# %%
#imports

import pyshdom
import numpy as np
import xarray as xr

# %% [markdown]
# ### Making the Table
#
# Pyshdom objects and methods typically are documented.

# %%
help(pyshdom.mie.get_mono_table)
# Out:
# Help on function get_mono_table in module pyshdom.mie:
#
# get_mono_table(particle_type, wavelength_band, minimum_effective_radius=4.0, max_integration_radius=65.0, wavelength_averaging=False, wavelength_resolution=0.001, refractive_index=None, relative_dir=None, verbose=True)
#     Mie monodisperse scattering for spherical particles.
#     This function will search a given directory to load the requested mie table or will compute it.
#     The table is returned as an xr Dataset.
#
#     Parameters
#     ----------
#     particle_type: string
#         Options are 'Water' or 'Aerosol'.
#     wavelength_band: (float, float)
#         (minimum, maximum) wavelength in microns.
#         This defines the spectral band over which to integrate, if both are equal
#         monochrome quantities are computed.
#     minimum_effective_radius: float
#         Minimum effective radius in microns. Used to compute minimum radius for integration.
#     max_integration_radius: float
#         Maximum radius in microns - cutoff for the size distribution integral
#     wavelength_averaging: bool
#         True - average scattering properties over the wavelength_band.
#         False - scattering properties of the central wavelength.
#     wavelength_resolution: float
#         The distance between two wavelength samples in the band. Used only if
#         wavelength_averaging is True.
#     refractive_index: complex number or None
#         For 'Water' the refractive index is ignored and loaded from a table
#         in src/polarized/indexwatice. For 'Aerosol' the refractive index should
#         have a negative imaginary part. ri = n - ik
#         For water with custom refractive index use 'Aerosol' particle type.
#     relative_dir: string
#         The path to a directory which contains saved mie_table netcdf files. If there is a file with
#         'mie_table' in the name that matches the input parameters this file is loaded.
#     verbose: bool
#         True for progress prints from the fortran computations.
#
#     Returns
#     -------
#     table: xr.Dataset
#         A Dataset containing tabulated Legendre coefficients per radius per wavelength.
#         Each entry has 6 six Wigner d-function elements of the Mie phase matrix
#         indexed by: P11, P22, P33, P44, P12, P34.
#
#     Notes
#     -----
#     Currently supports only 'Water' and 'Aerosol' particles ('Ice' is not yet implemented).
#
#     References
#     ----------
#     .. [1] Doicu, Adrian, Dmitry Efremenko, and Thomas Trautmann. "A multi-dimensional
#         vector spherical harmonics discrete ordinate method for atmospheric radiative transfer."
#         Journal of Quantitative Spectroscopy and Radiative Transfer 118 (2013): 121-131.
#         URL:http://dx.doi.org/10.1016/j.jqsrt.2012.12.009.

# %%
mie_mono_table = pyshdom.mie.get_mono_table(
    'Water',(0.86,0.86),
    max_integration_radius=65.0,
    minimum_effective_radius=0.1,
    relative_dir='../mie_tables',
    verbose=False
)
# verbose prints to standard out which is in the notebook terminal.

# %% [markdown]
# `get_mono_table` will first search a directory to see if the requested table exists
# otherwise it will calculate it. You can save it to see if it works.

# %%
mie_mono_table.to_netcdf('../mie_tables/test.nc')
mie_mono2 = pyshdom.mie.get_mono_table(
    'Water',(0.86,0.86),
    max_integration_radius=65.0,
    minimum_effective_radius=0.1,
    relative_dir='../mie_tables',
    verbose=True
)
print(mie_mono_table.equals(mie_mono2))
# Out:
# True

# %% [markdown]
# ### Using the Table
#
# The contents of mie_mono_table can be easily viewed with xarray's interface.
# The attributes record the inputs used to generate this table.
#
# To calculate optical properties typically you would integrate over a range of sizes. Pyshdom has
# tools for that in the pyshdom.size_distribution and pyshdom.medium modules that take
# datasets of the same format as `mie_mono_table` as input.
#
# SHDOM uses a Legendre/Wigner expansion of the phase functions rather than tabulated phase functions which
# are more common for MonteCarlo methods.

# %%
mie_mono_table
# Out:
# <xarray.Dataset>
# Dimensions:       (radius: 1444, stokes_index: 6, legendre_index: 1017)
# Coordinates:
#   * radius        (radius) float32 0.002 0.003369 0.004737 ... 64.88 64.97 65.06
#   * stokes_index  (stokes_index) <U3 'P11' 'P22' 'P33' 'P44' 'P12' 'P34'
# Dimensions without coordinates: legendre_index
# Data variables:
#     extinction    (radius) float32 1.83e-13 2.023e-12 ... 2.686e+04 2.706e+04
#     scatter       (radius) float32 6.358e-14 1.452e-12 ... 2.686e+04 2.706e+04
#     nleg          (radius) int32 4 6 6 6 6 6 6 ... 1010 1010 1012 1014 1014 1016
#     legendre      (stokes_index, legendre_index, radius) float32 6.358e-14 .....
# Attributes:
#     particle_type:               Water
#     refractive_index:            (1.3300000429153442, -2.893244186452648e-07)
#     refractive_index_source:     src/polarized/indexwatice.f
#     units:                       ['Radius [micron]', 'Wavelength [micron]']
#     wavelength_band:             (0.86, 0.86)
#     wavelength_center:           0.8600000143051147
#     wavelength_averaging:        False
#     wavelength_resolution:       0.001
#     maximum_legendre:            1016
#     minimum_effective_radius:    0.1
#     maximum_integration_radius:  65.0

# %% [markdown]
# ### Visualization
#
# `xarray`'s inbuilt plotting methods can be used and utility functions are available for evaluating the phase function at different scattering angles for visualization purposes.
# Note that we can evaluate the phase function for all of the radii or only some.

# %%
phase_function = pyshdom.util.get_phase_function(mie_mono_table.legendre[...,400], np.linspace(0.0,180.0,360), phase_elements='All')

# %%
phase_function
# Out:
# <xarray.DataArray 'phase_function' (phase_elements: 6, scattering_angle: 360)>
# array([[ 2.0276918e+08,  5.8404752e+07,  1.0588559e+06, ...,
#          1.1493096e+03,  1.2439675e+03,  9.4384346e+03],
#        [ 2.0276918e+08,  5.8404752e+07,  1.0588560e+06, ...,
#          1.1491841e+03,  1.2437484e+03,  9.4381680e+03],
#        [ 2.0276918e+08,  5.8402108e+07,  1.0574949e+06, ...,
#         -7.7616180e+02, -4.0230212e+02, -9.4381680e+03],
#        [ 2.0276918e+08,  5.8402108e+07,  1.0574949e+06, ...,
#         -7.7581189e+02, -4.0221976e+02, -9.4380762e+03],
#        [ 0.0000000e+00, -5.5391325e+05,  4.6952980e+04, ...,
#          4.4969824e+02,  8.6857837e+02,  0.0000000e+00],
#        [ 0.0000000e+00,  4.2265566e+04,  2.5997658e+04, ...,
#         -7.1894733e+02,  7.9419971e+02,  0.0000000e+00]], dtype=float32)
# Coordinates:
#   * phase_elements    (phase_elements) <U3 'P11' 'P22' 'P33' 'P44' 'P12' 'P34'
#   * scattering_angle  (scattering_angle) float64 0.0 0.5014 ... 179.5 180.0
#     radius            float32 32.65

# %%
phase_function[0].plot(yscale='log')

# %% [markdown]
# # Another way of getting access to the pahse function in spesific radius

# %%
phase_function = pyshdom.util.get_phase_function(mie_mono_table.legendre.isel(radius = 400), np.linspace(0.0,180.0,360), phase_elements='All')
phase_function[0].plot(yscale='log')

# %%
# mie_mono_table.legendre.sel(stokes_index='P11',radius=6.506141e+01) #, method="nearest")
mie_mono_table.legendre.sel(stokes_index='P11',radius=6.5e1, method="pad")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_35659/332266947.py in <module>
#       1 # mie_mono_table.legendre.sel(stokes_index='P11',radius=6.506141e+01) #, method="nearest")
# ----> 2 mie_mono_table.legendre.sel(stokes_index='P11',radius=6.5e1, method="pad")
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/xarray/core/dataarray.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1313         Dimensions without coordinates: points
#    1314         """
# -> 1315         ds = self._to_temp_dataset().sel(
#    1316             indexers=indexers,
#    1317             drop=drop,
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2472         """
#    2473         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2474         pos_indexers, new_indexes = remap_label_indexers(
#    2475             self, indexers=indexers, method=method, tolerance=tolerance
#    2476         )
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/xarray/core/coordinates.py in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     419     }
#     420
# --> 421     pos_indexers, new_indexes = indexing.remap_label_indexers(
#     422         obj, v_indexers, method=method, tolerance=tolerance
#     423     )
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/xarray/core/indexing.py in remap_label_indexers(data_obj, indexers, method, tolerance)
#     115     for dim, index in indexes.items():
#     116         labels = grouped_indexers[dim]
# --> 117         idxr, new_idx = index.query(labels, method=method, tolerance=tolerance)
#     118         pos_indexers[dim] = idxr
#     119         if new_idx is not None:
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/xarray/core/indexes.py in query(self, labels, method, tolerance)
#     222                     indexer = index.get_loc(label_value)
#     223                 else:
# --> 224                     indexer = index.get_loc(
#     225                         label_value, method=method, tolerance=tolerance
#     226                     )
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3085             tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#    3086
# -> 3087         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    3088         if indexer.ndim > 1 or indexer.size > 1:
#    3089             raise TypeError("get_loc requires scalar valued input")
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3174
#    3175         if method == "pad" or method == "backfill":
# -> 3176             indexer = self._get_fill_indexer(target, method, limit, tolerance)
#    3177         elif method == "nearest":
#    3178             indexer = self._get_nearest_indexer(target, limit, tolerance)
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_fill_indexer(self, target, method, limit, tolerance)
#    3215             indexer = engine_method(target_values, limit)
#    3216         else:
# -> 3217             indexer = self._get_fill_indexer_searchsorted(target, method, limit)
#    3218         if tolerance is not None and len(self):
#    3219             indexer = self._filter_indexer_tolerance(target_values, indexer, tolerance)
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_fill_indexer_searchsorted(self, target, method, limit)
#    3239         indexer = self.get_indexer(target)
#    3240         nonexact = indexer == -1
# -> 3241         indexer[nonexact] = self._searchsorted_monotonic(target[nonexact], side)
#    3242         if side == "left":
#    3243             # searchsorted returns "indices into a sorted array such that,
#
# ~/.conda/envs/new_pyshdom/lib/python3.9/site-packages/pandas/core/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    5352             return len(self) - pos
#    5353
# -> 5354         raise ValueError("index must be monotonic increasing or decreasing")
#    5355
#    5356     def get_slice_bound(self, label, side: str_t, kind) -> int:
#
# ValueError: index must be monotonic increasing or decreasing

# %%
mie_mono_table.legendre.radius.plot()
